# %%
import pandas as pd
import numpy as np
from google.colab import drive
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils import resample
from collections import defaultdict
import gc

# Mount Google Drive
drive.mount('/content/drive')

def print_summary(df, stage):
    print(f"\n--- Summary at {stage} ---")
    print(f"Shape: {df.shape}")
    print("\nColumns:")
    print(df.columns.tolist())
    print("\nValue counts of 'Label' column:")
    print(df['Label'].value_counts(normalize=True))
    if 'attack_cat' in df.columns:
        print("\nValue counts of 'attack_cat' column:")
        print(df['attack_cat'].value_counts(normalize=True))
    print("-----------------------------\n")
# Out:
# Mounted at /content/drive

# %%
# Step 1: Combine Dataset Files (with chunking)
def combine_datasets(chunk_size=100000):
    desired_features = [
        'Stime', 'Ltime', 'dur', 'proto', 'service', 'state', 'sbytes', 'dbytes', 'sttl', 'dttl',
        'sloss', 'dloss', 'sload', 'dload', 'spkts', 'dpkts', 'swin', 'dwin',
        'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len',
        'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 'ct_src_dport_ltm',
        'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label'
    ]

    # Read headers from the first file
    first_file = '/content/drive/MyDrive/UNSW-NB15_1.csv'
    available_columns = pd.read_csv(first_file, nrows=0).columns.tolist()

    # Use only the columns that are actually present in the file
    usecols = [col for col in desired_features if col in available_columns]

    print(f"Using the following columns: {usecols}")

    for i in range(1, 5):
        file_path = f'/content/drive/MyDrive/UNSW-NB15_{i}.csv'
        for chunk in pd.read_csv(file_path, usecols=usecols, chunksize=chunk_size, low_memory=False):
            yield process_chunk(chunk)

def process_chunk(chunk):
    if 'attack_cat' in chunk.columns:
        chunk['attack_cat'] = chunk['attack_cat'].fillna('Normal')
    if 'Label' in chunk.columns:
        chunk.loc[chunk['Label'] == 0, 'attack_cat'] = 'Normal'
    return chunk

# %%
# Step 2 & 3: Ground Truth Alignment and Attack Category Assignment
def align_ground_truth(df, gt):
    df['Stime'] = pd.to_datetime(df['Stime'], unit='s')
    df['Ltime'] = pd.to_datetime(df['Ltime'], unit='s')

    def find_attack_cat(row):
        if row['Label'] == 0:
            return 'Normal'
        mask = (gt['Start time'] <= row['Stime']) & (gt['Last time'] >= row['Ltime'])
        matching = gt[mask]
        if not matching.empty:
            return matching.iloc[0]['Attack category']
        return row['attack_cat']

    df['attack_cat'] = df.apply(find_attack_cat, axis=1)
    return df

# %%
# Step 4: Class Balancing
def balance_classes(df):
    print("Initial class distribution:")
    print(df['attack_cat'].value_counts())

    # Identify the majority class (assumed to be 'normal')
    majority_class = df['attack_cat'].mode().iloc[0]

    df_normal = df[df['attack_cat'] == majority_class]
    df_attack = df[df['attack_cat'] != majority_class]

    n_normal = len(df_normal)
    n_attack = len(df_attack)

    if n_normal == 0 or n_attack == 0:
        print("Unable to balance classes: one or both classes have zero samples.")
        return df

    attack_counts = df_attack['attack_cat'].value_counts()

    # Use the median of non-zero counts
    non_zero_counts = attack_counts[attack_counts > 0]
    if len(non_zero_counts) > 0:
        median_attack_count = int(non_zero_counts.median())
    else:
        median_attack_count = 1

    # Ensure we have at least 1 sample per category
    target_samples = max(1, median_attack_count)

    # Determine the number of samples for the normal class
    n_normal_samples = min(n_attack, n_normal, target_samples * len(attack_counts))

    if n_normal_samples == 0:
        print("After balancing, no normal samples would remain. Skipping balancing.")
        return df

    df_normal_downsampled = resample(df_normal,
                                     replace=False,
                                     n_samples=n_normal_samples,
                                     random_state=42)

    balanced_attacks = []
    for category in attack_counts.index:
        df_category = df_attack[df_attack['attack_cat'] == category]
        n_category = len(df_category)
        if n_category == 0:
            continue  # Skip empty categories
        elif n_category > target_samples:
            df_category = resample(df_category,
                                   replace=False,
                                   n_samples=target_samples,
                                   random_state=42)
        elif n_category < target_samples:
            df_category = resample(df_category,
                                   replace=True,
                                   n_samples=target_samples,
                                   random_state=42)
        balanced_attacks.append(df_category)

    if not balanced_attacks:
        print("No attack samples after balancing. Returning original dataset.")
        return df

    df_balanced = pd.concat([df_normal_downsampled] + balanced_attacks)
    df_balanced = df_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

    print("Final class distribution:")
    print(df_balanced['attack_cat'].value_counts())

    return df_balanced

# %%
# Step 5: Feature Engineering
def engineer_features(df):
    df['time_diff'] = (df['Ltime'] - df['Stime']).dt.total_seconds()
    df['hour'] = df['Stime'].dt.hour
    df['day_of_week'] = df['Stime'].dt.dayofweek
    df['is_weekend'] = df['day_of_week'].isin([5, 6]).astype(int)
    return df

# %%
# Step 6: Categorical Feature Encoding
def encode_categorical_features(df, encoders=None):
    if encoders is None:
        encoders = {}

    categorical_columns = ['proto', 'service', 'state', 'attack_cat']
    for col in categorical_columns:
        if col not in encoders:
            encoders[col] = LabelEncoder()
            encoders[col].fit(df[col])
        else:
            # Combine known and unknown labels
            labels = np.unique(np.concatenate((encoders[col].classes_, df[col].unique())))
            encoders[col].classes_ = labels

        # Transform the data, handling unknown labels
        df[col] = df[col].map(lambda x: x if x in encoders[col].classes_ else 'Unknown')
        df[col] = encoders[col].transform(df[col])

    return df, encoders

# %%
# Step 7: Normalization & Scaling
def normalize_features(df):
    scaler = StandardScaler()
    numerical_columns = df.select_dtypes(include=[np.number]).columns.drop(['Label', 'hour', 'day_of_week', 'is_weekend'])
    df[numerical_columns] = scaler.fit_transform(df[numerical_columns])
    return df

# %%
# Step 9: Normalization & Scaling (performed after processing all data)
def preprocess_unsw_nb15(output_file, chunk_size=100000):
    print("Loading ground truth data...")
    gt = pd.read_csv('/content/drive/MyDrive/UNSW-NB15_GT.csv')
    gt['Start time'] = pd.to_datetime(gt['Start time'])
    gt['Last time'] = pd.to_datetime(gt['Last time'])

    if 'Attack category' not in gt.columns:
        raise ValueError("'Attack category' column not found in ground truth file")

    print("Processing data in chunks...")
    encoders = None
    processed_chunks = []
    for i, chunk in enumerate(combine_datasets(chunk_size)):
        print(f"Processing chunk {i+1}")

        if 'Stime' in chunk.columns and 'Ltime' in chunk.columns:
            chunk = align_ground_truth(chunk, gt)

        if 'Stime' in chunk.columns:
            chunk = engineer_features(chunk)

        chunk, encoders = encode_categorical_features(chunk, encoders)

        print_summary(chunk, f"End of Chunk {i+1}")

        processed_chunks.append(chunk)

        del chunk
        gc.collect()

    print("Combining processed chunks...")
    df = pd.concat(processed_chunks, ignore_index=True)
    del processed_chunks
    gc.collect()

    print_summary(df, "After Combining All Chunks")

    if 'Label' in df.columns and 'attack_cat' in df.columns:
        print("Balancing classes...")
        df = balance_classes(df)
    else:
        print("'Label' or 'attack_cat' column missing. Skipping class balancing.")

    print("Normalizing features...")
    df = normalize_features(df)

    print("Saving preprocessed data...")
    df.to_csv(output_file, index=False)
    print(f"Preprocessed data saved to {output_file}")

    if 'attack_cat' in df.columns:
        print("\nFinal Distribution of attack categories:")
        print(df['attack_cat'].value_counts(normalize=True))

    return df

# %%
# Run the preprocessing
output_file = '/content/drive/MyDrive/preprocessed_unsw_nb15.csv'
preprocessed_df = preprocess_unsw_nb15(output_file)
# Out:
# Loading ground truth data...
# Processing data in chunks...
# Using the following columns: ['Stime', 'Ltime', 'dur', 'proto', 'service', 'state', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label']
# Processing chunk 1
#
# --- Summary at End of Chunk 1 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.8857
# 1    0.1143
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    0.88570
# 4    0.03374
# 0    0.03329
# 5    0.01820
# 7    0.00945
# 3    0.00862
# 2    0.00494
# 1    0.00464
# 8    0.00126
# 9    0.00016
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 2
#
# --- Summary at End of Chunk 2 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.89215
# 1    0.10785
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    0.89215
# 5    0.05702
# 4    0.02035
# 0    0.01722
# 7    0.00814
# 3    0.00305
# 8    0.00097
# 1    0.00062
# 2    0.00040
# 9    0.00008
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 3
#
# --- Summary at End of Chunk 3 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 4
#
# --- Summary at End of Chunk 4 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 5
#
# --- Summary at End of Chunk 5 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 6
#
# --- Summary at End of Chunk 6 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 7
#
# --- Summary at End of Chunk 7 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 8
#
# --- Summary at End of Chunk 8 ---
# Shape: (1, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 9
#
# --- Summary at End of Chunk 9 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 10
#
# --- Summary at End of Chunk 10 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 11
#
# --- Summary at End of Chunk 11 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    1.0
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 6    1.0
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 12
#
# --- Summary at End of Chunk 12 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.99236
# 1    0.00764
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.99236
# 8     0.00315
# 1     0.00194
# 2     0.00121
# 7     0.00066
# 9     0.00041
# 3     0.00015
# 5     0.00006
# 4     0.00003
# 13    0.00003
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 13
#
# --- Summary at End of Chunk 13 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.80902
# 1    0.19098
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.80902
# 9     0.09960
# 8     0.03788
# 7     0.02345
# 1     0.01289
# 2     0.01065
# 5     0.00280
# 4     0.00254
# 3     0.00104
# 13    0.00013
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 14
#
# --- Summary at End of Chunk 14 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.86543
# 1    0.13457
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.86543
# 9     0.07774
# 8     0.02304
# 1     0.01814
# 2     0.00913
# 7     0.00386
# 3     0.00108
# 4     0.00096
# 5     0.00051
# 13    0.00011
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 15
#
# --- Summary at End of Chunk 15 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.8057
# 1    0.1943
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.80570
# 9     0.10108
# 8     0.04696
# 7     0.01840
# 1     0.01371
# 2     0.01017
# 4     0.00255
# 3     0.00097
# 5     0.00033
# 13    0.00013
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 16
#
# --- Summary at End of Chunk 16 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.72232
# 1    0.27768
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.72232
# 9     0.24669
# 8     0.01261
# 1     0.00872
# 2     0.00558
# 7     0.00230
# 4     0.00079
# 3     0.00063
# 5     0.00030
# 13    0.00006
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 17
#
# --- Summary at End of Chunk 17 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.85768
# 1    0.14232
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.85768
# 9     0.09009
# 8     0.02158
# 1     0.01681
# 2     0.00837
# 7     0.00382
# 3     0.00105
# 5     0.00043
# 13    0.00010
# 4     0.00007
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 18
#
# --- Summary at End of Chunk 18 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.67868
# 1    0.32132
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.67868
# 9     0.23780
# 8     0.04019
# 7     0.01745
# 1     0.01082
# 2     0.00885
# 5     0.00276
# 4     0.00252
# 3     0.00081
# 13    0.00012
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 19
#
# --- Summary at End of Chunk 19 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.74998
# 1    0.25002
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.74998
# 9     0.20800
# 8     0.01686
# 1     0.01229
# 2     0.00672
# 7     0.00305
# 4     0.00186
# 3     0.00082
# 5     0.00034
# 13    0.00008
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 20
#
# --- Summary at End of Chunk 20 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.83098
# 1    0.16902
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.83098
# 9     0.06759
# 8     0.04124
# 7     0.02383
# 1     0.01616
# 2     0.01350
# 5     0.00295
# 4     0.00253
# 3     0.00109
# 13    0.00013
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 21
#
# --- Summary at End of Chunk 21 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.74963
# 1    0.25037
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.74963
# 9     0.22072
# 8     0.01319
# 1     0.00806
# 2     0.00510
# 7     0.00219
# 3     0.00056
# 5     0.00030
# 4     0.00019
# 13    0.00006
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 22
#
# --- Summary at End of Chunk 22 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.83648
# 1    0.16352
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.83648
# 9     0.11109
# 8     0.02007
# 1     0.01851
# 2     0.00770
# 7     0.00378
# 3     0.00097
# 4     0.00077
# 5     0.00051
# 13    0.00012
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 23
#
# --- Summary at End of Chunk 23 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.80539
# 1    0.19461
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.80539
# 9     0.10705
# 8     0.04066
# 7     0.02046
# 1     0.01023
# 2     0.00977
# 5     0.00279
# 4     0.00256
# 3     0.00096
# 13    0.00013
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 24
#
# --- Summary at End of Chunk 24 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.76842
# 1    0.23158
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.76842
# 9     0.19915
# 8     0.01366
# 1     0.00874
# 2     0.00548
# 7     0.00275
# 4     0.00079
# 3     0.00058
# 5     0.00037
# 13    0.00006
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 25
#
# --- Summary at End of Chunk 25 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.87576
# 1    0.12424
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.87576
# 9     0.04148
# 8     0.03274
# 1     0.01819
# 7     0.01583
# 2     0.01076
# 5     0.00211
# 4     0.00180
# 3     0.00118
# 13    0.00015
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 26
#
# --- Summary at End of Chunk 26 ---
# Shape: (100000, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.73521
# 1    0.26479
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.73521
# 9     0.21771
# 8     0.01885
# 1     0.01128
# 7     0.00802
# 2     0.00623
# 5     0.00110
# 4     0.00087
# 3     0.00066
# 13    0.00007
# Name: proportion, dtype: float64
# -----------------------------
#
# Processing chunk 27
#
# --- Summary at End of Chunk 27 ---
# Shape: (40044, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.815903
# 1    0.184097
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.815903
# 9     0.133328
# 8     0.021177
# 1     0.013635
# 2     0.007642
# 7     0.005019
# 4     0.001698
# 3     0.000824
# 5     0.000724
# 13    0.000050
# Name: proportion, dtype: float64
# -----------------------------
#
# Combining processed chunks...
#
# --- Summary at After Combining All Chunks ---
# Shape: (2540045, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.873513
# 1    0.126487
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
# 10    0.488565
# 6     0.384948
# 9     0.081882
# 8     0.015488
# 1     0.007764
# 7     0.006671
# 2     0.005024
# 5     0.003668
# 4     0.002976
# 0     0.001989
# 3     0.000967
# 13    0.000059
# Name: proportion, dtype: float64
# -----------------------------
#
# Balancing classes...
# Initial class distribution:
# attack_cat
# 10    1240976
# 6      977786
# 9      207983
# 8       39339
# 1       19721
# 7       16945
# 2       12762
# 5        9317
# 4        7560
# 0        5051
# 3        2455
# 13        150
# Name: count, dtype: int64
# Final class distribution:
# attack_cat
# 10    140382
# 5      12762
# 6      12762
# 1      12762
# 3      12762
# 9      12762
# 4      12762
# 7      12762
# 8      12762
# 13     12762
# 2      12762
# 0      12762
# Name: count, dtype: int64
# Normalizing features...
# Saving preprocessed data...
# Preprocessed data saved to /content/drive/MyDrive/preprocessed_unsw_nb15.csv
#
# Final Distribution of attack categories:
# attack_cat
#  0.673340    0.500000
# -0.751033    0.045455
# -0.466159    0.045455
# -1.890532    0.045455
# -1.320783    0.045455
#  0.388465    0.045455
# -1.035908    0.045455
# -0.181284    0.045455
#  0.103591    0.045455
#  1.527964    0.045455
# -1.605657    0.045455
# -2.175407    0.045455
# Name: proportion, dtype: float64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f7256cc50942> in <cell line: 6>()
#       4
#       5 # Final display of preprocessed data
# ----> 6 print_df_info(preprocessed_df, "Final Preprocessed Data")
#
# NameError: name 'print_df_info' is not defined

# %%
# Final display of preprocessed data
print_summary(preprocessed_df, "Final Preprocessed Data")
# Out:
# --- Summary at Final Preprocessed Data ---
# Shape: (280764, 32)
#
# Columns:
# ['proto', 'state', 'dur', 'sbytes', 'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 'trans_depth', 'res_bdy_len', 'Stime', 'Ltime', 'ct_state_ttl', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm', 'attack_cat', 'Label', 'time_diff', 'hour', 'day_of_week', 'is_weekend']
#
# Value counts of 'Label' column:
# Label
# 0    0.545455
# 1    0.454545
# Name: proportion, dtype: float64
#
# Value counts of 'attack_cat' column:
# attack_cat
#  0.673340    0.500000
# -0.751033    0.045455
# -0.466159    0.045455
# -1.890532    0.045455
# -1.320783    0.045455
#  0.388465    0.045455
# -1.035908    0.045455
# -0.181284    0.045455
#  0.103591    0.045455
#  1.527964    0.045455
# -1.605657    0.045455
# -2.175407    0.045455
# Name: proportion, dtype: float64
# -----------------------------
